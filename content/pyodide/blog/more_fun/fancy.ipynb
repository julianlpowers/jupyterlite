# %%
# --- Cell 1: Imports ---
# Import all necessary modules for 3D visualization
# %pip install "pyvista[all]"

import pyvista as pv
# Out:
# ...
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata (8.7 kB)
# ...
#   Using cached trame-3.12.0-py3-none-any.whl.metadata (8.2 kB)
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# ...
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# ...
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# ...
#    ---------------------------------------- 0.0/751.5 kB ? eta -:--:--
#    ---------------------------------------- 751.5/751.5 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# --- Cell 2: Load STL from PyVista examples ---
# Get STL path from PyVista examples
stl = pv.examples.download_crater_topo()

# Plot the mesh
plotter = pv.Plotter()
plotter.add_mesh(stl, show_edges=True)

# plotter.view_xy()
plotter.show(jupyter_backend='trame')
# Out:
# Widget(value='<iframe src="http://localhost:62192/index.html?ui=P_0x1fff5a08b90_9&reconnect=auto" class="pyvis…
